# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span></li><li><span><a href="#Challenge-1---Exploring-the-Data" data-toc-modified-id="Challenge-1---Exploring-the-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Challenge 1 - Exploring the Data</a></span></li><li><span><a href="#Challenge-2---Hypothesis-Tests" data-toc-modified-id="Challenge-2---Hypothesis-Tests-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Challenge 2 - Hypothesis Tests</a></span></li><li><span><a href="#Challenge-3:-To-practice---Constructing-Confidence-Intervals" data-toc-modified-id="Challenge-3:-To-practice---Constructing-Confidence-Intervals-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Challenge 3: To practice - Constructing Confidence Intervals</a></span></li><li><span><a href="#Bonus-Challenge---Hypothesis-Tests-of-Proportions" data-toc-modified-id="Bonus-Challenge---Hypothesis-Tests-of-Proportions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Bonus Challenge - Hypothesis Tests of Proportions</a></span></li></ul></div>

# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd
from scipy import stats

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents. Please, load the csv as a pandas dataframe named `salaries` from the data folder of this repository (Current_Employee_Names__Salaries__and_Position_Titles.csv).
#
#
# Each row is one employee.

# %%
salaries = pd.read_csv("../data/Current_Employee_Names__Salaries__and_Position_Titles.csv")

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
salaries.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
### sum the values axis 0, by column
salaries.isnull().sum(axis = 0)
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25161
# Annual Salary         8022
# Hourly Rate          25161
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below. How many workers we have on salary and hourly.

# %%
salaries["Salary or Hourly"].value_counts()
#we have more many employees on salary
# Out:
# Salary    25161
# Hourly     8022
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
salaries["Department"].value_counts()
#we have this amount of employees by department
# Out:
# POLICE                   13414
# FIRE                      4641
# STREETS & SAN             2198
# OEMC                      2102
# WATER MGMNT               1879
# AVIATION                  1629
# TRANSPORTN                1140
# PUBLIC LIBRARY            1015
# GENERAL SERVICES           980
# FAMILY & SUPPORT           615
# FINANCE                    560
# HEALTH                     488
# CITY COUNCIL               411
# LAW                        407
# BUILDINGS                  269
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           171
# COPA                       116
# BOARD OF ELECTION          107
# DoIT                        99
# PROCUREMENT                 92
# INSPECTOR GEN               87
# MAYOR'S OFFICE              85
# CITY CLERK                  84
# ANIMAL CONTRL               81
# HUMAN RESOURCES             79
# CULTURAL AFFAIRS            65
# BUDGET & MGMT               46
# ADMIN HEARNG                39
# DISABILITIES                28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
salaries[salaries["Salary or Hourly"] == "Hourly"]
# Out:
#                          Name                      Job Titles  \
# 4           ABASCAL,  REECE E     TRAFFIC CONTROL AIDE-HOURLY
# 6       ABBATACOLA,  ROBERT J             ELECTRICAL MECHANIC
# 7          ABBATE,  JOSEPH L          POOL MOTOR TRUCK DRIVER
# 10           ABBOTT,  BETTY L              FOSTER GRANDPARENT
# 18       ABDULLAH,  LAKENYA N                  CROSSING GUARD
# ...                       ...                             ...
# 33164        ZUREK,  FRANCIS              ELECTRICAL MECHANIC
# 33168  ZWARYCZ MANN,  IRENE A                  CROSSING GUARD
# 33169      ZWARYCZ,  THOMAS J         POOL MOTOR TRUCK DRIVER
# 33174        ZYGADLO,  JOHN P          MACHINIST (AUTOMOTIVE)
# 33175     ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 4                  OEMC                 P           Hourly           20.0
# ...

# %%
sample = salaries[salaries["Salary or Hourly"] == "Hourly"]["Hourly Rate"]
sample
# Out:
# 4        19.86
# 6        46.10
# 7        35.60
# 10        2.65
# 18       17.68
#          ...
# 33164    46.10
# 33168    17.68
# 33169    35.60
# 33174    46.35
# 33175    48.85
# Name: Hourly Rate, Length: 8022, dtype: float64

# %%
mu = 30

# %%
## sample size

sample_size = salaries[salaries["Salary or Hourly"] == "Hourly"].shape [0]
sample_size
# Out:
# 8022

# %%
#I need to select from the data set the workers with hourly wage

sample_mean = salaries[salaries["Salary or Hourly"] == "Hourly"]["Hourly Rate"].mean()
sample_mean

##is the same as underneath because just the hourly employees have hourly wage
# Out:
# 32.78855771628128

# %%
## I will get the sample standard deviation


sample_st = salaries[salaries["Salary or Hourly"] == "Hourly"]["Hourly Rate"].std()
sample_st
# Out:
# 12.11257268427681

# %%
# The "Sample distribution of the sample mean" has these 3 properties:
    # 1) its mean is equal to the mean of the population (we're assuming it's 2kg)
    # 2) its standard deviation is equal to the standard error of our estimate (we computed it as 'sem')
    # 3) it resembles a normal distribution.

# %%
##This is mu: $30/hr
###1. Nul hypothesis--> mu = 30
### 2. Alternative hypothesis--> mu != 30
###compute weather the hourly rate is greater or less than a certain range of values, with a two sided test 
#(because the difference can be positive or negative: sample.mean - mu > 0, sample.mean -mu > 0)
### 3. decide the statistic. the sample size is really big so we will use a statistic from the normal distribution.
###4. confidence interval 95% (two sided confidence interval),that means a significance level of 0.05/2 per side

# %%
###5. we want to calculate our statistic
# Z = sample.mean - mu / standard error
# standard error = population standard deviation/sqrt root of sample size 
#if we don't have the standard deviation for the population we can use the corrected sample standard deviation

sem = sample_st/np.sqrt(sample_size)
sem
# Out:
# 0.1352368565101597

# %%
### I calculate the t-statistic

statistic = (sample_mean - mu)/sem
statistic
# Out:
# 20.619805785501907

# %%
##we can use this function that calculates the statistics directly 
# This is a two-sided test for the null hypothesis that the expected value (mean) of a
# sample of independent observations a is equal to the given population mean, popmean.
# With this function we enter the observed values, the sample, and then the mean for ho (mu)
stats.ttest_1samp(sample,30)
#same result of before.
# Out:
# Ttest_1sampResult(statistic=20.6198057854942, pvalue=4.3230240486229894e-92)

# %%
#6.we calculate the critical value with our confidence interval, is two sided so we take in account the area
#until (0.05/2)
critical_value = stats.norm.ppf(1-(0.05/2))

# %% [markdown]
# ![IMG_3754.jpg](attachment:IMG_3754.jpg)

# %%
#Our t-statistic is in the rejection area, therefore we reject Ho.  
#hourly wage of all hourly workers is significantly different from $30/hr.

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
salaries[salaries["Department"] == "POLICE"]
# Out:
#                          Name                              Job Titles  \
# 0           AARON,  JEFFERY M                                SERGEANT
# 1             AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 9            ABBATE,  TERRY M                          POLICE OFFICER
# 11           ABDALLAH,  ZAID                           POLICE OFFICER
# 12     ABDELHADI,  ABDALMAHD                           POLICE OFFICER
# ...                       ...                                     ...
# 33177        ZYGMUNT,  DAWID                           POLICE OFFICER
# 33178   ZYLINSKA,  KATARZYNA                           POLICE OFFICER
# 33179      ZYMANTAS,  LAURA C                          POLICE OFFICER
# 33180       ZYMANTAS,  MARK E                          POLICE OFFICER
# 33181     ZYRKOWSKI,  CARLO E                          POLICE OFFICER
#
#       Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %%
salaries[(salaries["Department"] == "POLICE") & (salaries["Salary or Hourly"] == "Hourly")]
#the null values are those hourly contracts within the police department, I have to impove my filter
# Out:
#                       Name    Job Titles Department Full or Part-Time  \
# 1811        BEAN,  VAUGHN   PROGRAM AIDE     POLICE                 P
# 3261       BROWN,  RONNIE   PROGRAM AIDE     POLICE                 P
# 4991   CIPUN,  CHRISTINA M  PROGRAM AIDE     POLICE                 P
# 9952      GARCIA,  ROBERT   POLICE CADET     POLICE                 P
# 11580     HAGUE,  JACKSON   PROGRAM AIDE     POLICE                 P
# 19135   MCMILLON,  MALIK M  PROGRAM AIDE     POLICE                 P
# 20104      MOORE,  KEMON J  PROGRAM AIDE     POLICE                 P
# 20159     MORALES,  ALBA M  POLICE CADET     POLICE                 P
# 24060     RAMIREZ,  JAMIE   PROGRAM AIDE     POLICE                 P
# 30174      TYLER,  JUSTIN   PROGRAM AIDE     POLICE                 P
#
#       Salary or Hourly  Typical Hours  Annual Salary  Hourly Rate
# 1811            Hourly           20.0            NaN         9.27
# ...

# %%
salaries[(salaries["Department"] == "POLICE")]['Salary or Hourly'].value_counts()
# Out:
# Salary    13404
# Hourly       10
# Name: Salary or Hourly, dtype: int64

# %%
#I have null values
salaries[(salaries["Department"] == "POLICE")]["Annual Salary"].isna().value_counts()
# Out:
# False    13404
# True        10
# Name: Annual Salary, dtype: int64

# %%
sample_police = salaries[(salaries["Department"] == "POLICE") & (salaries["Salary or Hourly"] == "Salary")]["Annual Salary"]
sample_police
# Out:
# 0        101442.0
# 1         94122.0
# 9         93354.0
# 11        84054.0
# 12        87006.0
#            ...
# 33177     72510.0
# 33178     72510.0
# 33179     48078.0
# 33180     90024.0
# 33181     93354.0
# Name: Annual Salary, Length: 13404, dtype: float64

# %%
sample_police.shape # there sample size is 13404, big
# Out:
# (13404,)

# %%
sample_police.isna().sum()
# Out:
# 0

# %%
###salaries this year are higher than last year's mean of $86000/year, mu = 86000
#Ho : mu = 86000
# Ha: sample_mean > 86000 (one tail test), right tail
# Statistic --> we will use the t-student ditribution, an we have to calculate the standard error with 
# the sample standard deviation
# our confidence interval is 95%

# %%
#the t-statistic is:

stats.ttest_1samp(sample_police,86000)
# Out:
# Ttest_1sampResult(statistic=3.081997005712994, pvalue=0.0020603403550965137)

# %%
#the critical value 
#df = n-1 = 13404-1 = 13403
stats.t.ppf(0.95,df= 13403)
# Out:
# 1.6449673235204956

# %%
#t-score =  3.081997005712994
#t- critical =  1.6449673235204956

#The t statistic is bigger than de t-critical so I am in the rejection area
#I will reject de Ho,we conlcude the average annual salary is significantly higher than $86000/year

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.
#
# Sort by hourly.

# %%
# Compute a simple cross tabulation of two (or more) factors. By default computes a frequency table of the factors 
#unless an array of values and an aggregation function are passed.
#index:array-like, Series, or list of arrays/Series-- Values to group by in the rows
# columns: array-like, Series, or list of arrays/Series-- Values to group by in the columns.

# %%
pd.crosstab(salaries["Department"],salaries["Salary or Hourly"]).sort_values('Hourly', ascending=False)
#Streers and san is the department with the most hourly workers
# Out:
# Salary or Hourly       Hourly  Salary
# Department
# STREETS & SAN            1862     336
# WATER MGMNT              1513     366
# OEMC                     1273     829
# AVIATION                 1082     547
# GENERAL SERVICES          765     215
# TRANSPORTN                725     415
# PUBLIC LIBRARY            299     716
# FAMILY & SUPPORT          287     328
# CITY COUNCIL               64     347
# FINANCE                    44     516
# LAW                        40     367
# ANIMAL CONTRL              19      62
# POLICE                     10   13404
# MAYOR'S OFFICE              8      77
# BUSINESS AFFAIRS            7     164
# CULTURAL AFFAIRS            7      58
# COMMUNITY DEVELOPMENT       4     203
# HUMAN RESOURCES             4      75
# HEALTH                      3     485
# PROCUREMENT                 2      90
# FIRE                        2    4639
# BUDGET & MGMT               2      44
# HUMAN RELATIONS             0      16
# ...

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
salaries[salaries["Department"] == "STREETS & SAN"]
# Out:
#                          Name               Job Titles     Department  \
# 7          ABBATE,  JOSEPH L   POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 21      ABDUL-SHAKUR,  TAHIR     GENERAL LABORER - DSS  STREETS & SAN
# 24     ABERCROMBIE,  TIMOTHY        MOTOR TRUCK DRIVER  STREETS & SAN
# 36        ABRAMS,  DANIELLE T       SANITATION LABORER  STREETS & SAN
# 39          ABRAMS,  SAMUEL A  POOL MOTOR TRUCK DRIVER  STREETS & SAN
# ...                       ...                      ...            ...
# 33107         ZIZUMBO,  LUIS        MOTOR TRUCK DRIVER  STREETS & SAN
# 33147        ZUMMO,  ROBERT J       MOTOR TRUCK DRIVER  STREETS & SAN
# 33149     ZUNICH,  JONATHAN G       SANITATION LABORER  STREETS & SAN
# 33156        ZUNIGA,  THOMAS     GENERAL LABORER - DSS  STREETS & SAN
# 33162       ZURAWSKI,  MAC Z   REFUSE COLLECTION COORD  STREETS & SAN
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# ...

# %%
salaries[salaries["Department"] == "STREETS & SAN"]["Hourly Rate"]
# Out:
# 7        35.60
# 21       21.43
# 24       35.60
# 36       36.21
# 39       35.60
#          ...
# 33107    35.60
# 33147    35.60
# 33149    36.21
# 33156    22.12
# 33162      NaN
# Name: Hourly Rate, Length: 2198, dtype: float64

# %%
### I am gonna check if we have null values, we do

salaries[salaries["Department"] == "STREETS & SAN"]["Hourly Rate"].isna().value_counts()
# Out:
# False    1862
# True      336
# Name: Hourly Rate, dtype: int64

# %%
salaries[(salaries["Department"] == "STREETS & SAN") & (salaries["Salary or Hourly"] == "Salary")]
# Out:
#                       Name                                   Job Titles  \
# 61     ACCIARI,  MICHAEL G                      DIVISION SUPERINTENDENT
# 221       AGUILAR,  IRENE                              SANITATION CLERK
# 306     AKRES,  DANIELLE N                             SANITATION CLERK
# 367      ALDUGOM,  NABIL K                             SANITATION CLERK
# 788    ANDERSON,  RHONDA M              PROPERTY CUSTODIAN - AUTO POUND
# ...                    ...                                          ...
# 32898     ZAHDAN,  MOEEN D                          WARD SUPERINTENDENT
# 32977    ZARO,  NICHOLAS J                      DIVISION SUPERINTENDENT
# 33015      ZEFRAN,  JOHN L  ASST GENERAL SUPT OF STREETS AND SANITATION
# 33045       ZEPEDA,  LUIS   ASST GENERAL SUPT OF STREETS AND SANITATION
# 33162    ZURAWSKI,  MAC Z                       REFUSE COLLECTION COORD
#
#           Department Full or Part-Time Salary or Hourly  Typical Hours  \
# ...

# %%
salaries[(salaries["Department"] == "STREETS & SAN") & (salaries["Salary or Hourly"] == "Salary")]["Hourly Rate"].isna().value_counts()

### again we have to filter by the hourly employees that is where we have the NaN values
# Out:
# True    336
# Name: Hourly Rate, dtype: int64

# %%
salaries[(salaries["Department"] == "STREETS & SAN") & (salaries["Salary or Hourly"] == "Hourly")]["Hourly Rate"].isna().value_counts()
#Perfect! No NaN in this subset
# Out:
# False    1862
# Name: Hourly Rate, dtype: int64

# %%
sample_streets = salaries[(salaries["Department"] == "STREETS & SAN") & (salaries["Salary or Hourly"] == "Hourly")]["Hourly Rate"]

# %%
sample_streets.size #enough big the sample size, we can use normal distribution or t for the sampling
# Out:
# 1862

# %%
#1. Ho: mu = 35
#2.Ha: sample_mean < 35 
#3. one test(left tail, negative value), I go with the normal distribution
#4. Confidence interval 95 %

# %%
#5. Compute the Z statistic:

stats.ttest_1samp(sample_streets,35)
# Out:
# Ttest_1sampResult(statistic=-9.567447887848152, pvalue=3.3378530564707717e-21)

# %%
# 6. Compute the Z critical. If I place, 95 i get the posistive number, as i want the left tail, i will place 
#0.05

stats.norm.ppf(0.05)
# Out:
# -1.6448536269514729

# %%
#As my statistic is smaller and I am doing a one side left tail test, it falls in the rejection area and I
#reject the null hypothesis. I conclude the average salary for those employees is significatnly smaller than
#35

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
###mean hourly wage of all hourly workers.

salaries[salaries["Salary or Hourly"] == "Hourly"]["Hourly Rate"].isna().value_counts()

sample_hourly = salaries[salaries["Salary or Hourly"] == "Hourly"]["Hourly Rate"]

# %%
# we compute de df = n-1
sample_hourly_size = sample_hourly.size
sample_hourly_df= sample_hourly_size -1
sample_hourly_df
# Out:
# 8021

# %%
##we calculate the sample mean
sample_hourly_mean = sample_hourly.mean()
sample_hourly_mean
# Out:
# 32.78855771628128

# %%
##we compute the sample standard deviation to compute the standard error
sample_hourly_st = sample_hourly.std()
sample_hourly_st
# Out:
# 12.11257268427681

# %%
#compute standard error
sample_hourly_sem = sample_hourly_st/np.sqrt(sample_hourly_size)
sample_hourly_sem
# Out:
# 0.1352368565101597

# %%
# This function computes it direclty
stats.sem(sample_hourly)
# Out:
# 0.1352368565101596

# %%
#we use stats.t --> mehtod : .interval(alpha, df, loc, scale), loc is the mean, and scale the standard error
stats.t.interval(0.95,sample_hourly_df,sample_hourly_mean, sample_hourly_sem )
# Out:
# (32.52345834488529, 33.05365708767727)

# %%
# (32.52345834488529, 33.05365708767727) This is the confidence interval
# So for a 95% confidence interval, we are 95% sure that the mean of the population 
#is within the confidence interval.

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
salaries[(salaries["Department"] == "POLICE") & (salaries["Salary or Hourly"] == "Salary")]["Annual Salary"].isna().value_counts()
# Out:
# False    13404
# Name: Annual Salary, dtype: int64

# %%
sample_police_salary = salaries[(salaries["Department"] == "POLICE") & (salaries["Salary or Hourly"] == "Salary")]["Annual Salary"]

# %%
sample_police_salary_mean = sample_police_salary.mean()

# %%
sample_police_salary_df = sample_police_salary.size - 1

# %%
sample_police_salary_sem = stats.sem(sample_police_salary)

# %%
#confidence interval

stats.t.interval(0.95,sample_police_salary_df,sample_police_salary_mean, sample_police_salary_sem)
# Out:
# (86177.05631531784, 86795.77269094894)

# %%
# We could do it by ourselves, computing the corresponding Zcritical values for 95 (how many standard deviations
#we subrtact)
# The confidence interval take those values: sample.mean +- Zscore at 95% * (se, or pop.stand_dev) 
#where se = sample.standard_dev/squareroot of n
# 
stats.norm.ppf(1-(0.05/2))
stats.norm.ppf(0.05/2)
# Out:
# -1.9599639845400545

# %%
sample_police_salary_mean  + stats.norm.ppf(1-(0.05/2))*sample_police_salary_sem
# Out:
# 86795.74475424402

# %%
sample_police_salary_mean  + stats.norm.ppf(0.05/2)*sample_police_salary_sem
# Out:
# 86177.08425202276

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
salaries[salaries["Salary or Hourly"] == "Salary"].shape[0]
# Out:
# 25161

# %%
salaries.shape[0]
# Out:
# 33183

# %%
# Your code here:
from statsmodels.stats.proportion import proportions_ztest

# Ho: the proportion of hourly workers is equal to 25% (H0: p = p0 (population proportion is equal to hypothesized proportion p0))
# Ha: the proportion of hourly workers is different to 25%.

#z = (p-p0) / √p0(1-p0)/n
#p: observed sample proportion
#p0: hypothesized population proportion
#n: sample size
#proportions_ztest(count, nobs, value=None, alternative=’two-sided’) 

#p0: hypothesized population proportion = 0.25
#x: hourly_workers 25161
#n: sample size = 33183

sample_success = salaries[salaries["Salary or Hourly"] == "Salary"].shape[0]
sample_size = salaries.shape[0]
null_hypothesis = 0.25


stat, pval = proportions_ztest(count=sample_success, nobs=sample_size, value=null_hypothesis ,alternative="two-sided")
stat,pval

#don't get the same result
#in any case p-value is 0, aplha 0.05, i reject the null hypothesis, concludint that the proportion of hourly
#workers in chicago is significantly different than 25%.
# Out:
# (216.2446288420654, 0.0)

# %%
#critical values
stats.norm.ppf(1-(0.05/2))
stats.norm.ppf(0.05/2)
# Out:
# -1.9599639845400545

# %%
# Out:
# Null hypothesis rejected
# Statistic:  -3.5099964213703005
# p-value:  0.0004481127249057967
